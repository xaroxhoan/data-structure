# %% [raw]
# https://en.wikipedia.org/wiki/List_of_data_structures
#
# 1. List
# 2. Stack
# 3. Queue
# 4. Tree
#   4.1. Binary trees
#     4.1.1. AA tree
#     4.1.2. AVL tree
#     4.1.3. Binary search tree
#     4.1.4. Binary tree
#     4.1.5. Cartesian tree
#     4.1.6. Conc-tree list
#     4.1.7. Left-child right-sibling binary tree
#     4.1.8. Order static tree
#     4.1.9. Pagoda
#     4.1.10. Randomized binary search tree
#     4.1.11. Red-Black tree
#     4.1.10. Rope
#     4.1.12. Scapegoat tree
#     4.1.13. Self-balancing binary search tree
#     4.1.14. splay tree
#     4.1.15. T-tree
#     4.1.16. Tango tree
#     4.1.17. Threaded binary tree
#     4.1.18. Top tree
#     4.1.19. WAVL tree
#     4.1.20. Weight-balanced tree
#     4.1.21. Zip tree
#   4.2. B-trees
#     4.2.1. B-tree
#     4.2.2. B+ tree
#     4.2.3. B*-tree
#     4.2.4. Dancing tree
#     4.2.5. 2-3 tree
#     4.2.6. 2-3-4 tree
#     4.2.7. Queap
#     4.2.8. Fusion tree
#     4.2.9. Bx-tree
#   4.3. Heaps
#     4.3.1. Heap
#     4.3.2. Min-max heap
#     4.3.3. Binary heap
#     4.3.4. B-heap
#     4.3.5. Weak heap
#     4.3.6. Binomial heap
#     4.3.7. Fibonacci heap
#     4.3.8. AF-heap
#     4.3.9. Leonardo heap
#     4.3.10. 2-3 heap
#     4.3.11. soft heap
#     4.3.12. Pairing heap
#     4.3.13. Leftist heap
#     4.3.14. Treap
#     4.3.15. Beap
#     4.3.16. Skew heap
#     4.3.17. Ternary heap
#     4.3.18. D-ary heap
#     4.3.19. Brodal queue
#   4.4. Bit-slice trees
#     4.4.1. Radix tree
#     4.4.2. Suffix tree
#     4.4.3. Suffix array
#     4.4.4. Compressed suffix array
#     4.4.5. FM-index
#     4.4.6. Generalized suffix tree
#     4.4.7. B-tree
#     4.4.8. Judy array
#     4.4.9. Trie
#     4.4.10. X-fast trie
#     4.4.11. Y-fast trie
#     4.4.12. Merkle tree
#   4.5 Multi-way trees
#     4.5.1. Ternary search tree
#     4.5.2. Ternary tree
#     4.5.3. K-ary tree
#     4.5.4. And-or tree
#     4.5.5. (a,b) tree
#     4.5.6. Link/cut tree
#     4.5.7. SPQR tree
#     4.5.8. Spaghetti stack
#     4.5.9. Disjoint-set data structure (Union-find data structure)
#     4.5.10. Fusion tree
#     4.5.11. Enfilade
#     4.5.12. Exponential tree
#     4.5.13. Fenwick tree
#     4.5.14. Van Emde Boas tree
#     4.5.15. Rose tree
#   4.6. Space-partitioning trees
#     4.6.1. Segment tree
#     4.6.2. Interval tree
#     4.6.3. Range tree
#     4.6.4. Bin
#     4.6.5. K-d tree
#     4.6.6. Implicit k-d tree
#     4.6.7. Min/max k-d tree
#     4.6.8. Relaxed k-d tree
#     4.6.9. Adaptive k-d tree
#     4.6.10. Quadtree
#     4.6.11. Octree
#     4.6.12. Linear octree
#     4.6.13. Z-order
#     4.6.14. UB-tree
#     4.6.15. R-tree
#     4.6.16. R+ tree
#     4.6.17. R* tree
#     4.6.18. Hilbert R-tree
#     4.6.19. X-tree
#     4.6.20. Metric tree
#     4.6.21. Cover tree
#     4.6.22. M-tree
#     4.6.23. VP-tree
#     4.6.24. BK-tree
#     4.6.25. Bounding interval hierarchy
#     4.6.26. Bounding volume hierarchy
#     4.6.27. BSP tree
#     4.6.28. Rapidly exploring random tree
#   4.7. Application-specific trees
#     4.7.1. Abstract syntax tree
#     4.7.2. Parse tree
#     4.7.3. Decision tree
#     4.7.4. Alternating decision tree
#     4.7.5. Minmax tree
#     4.7.6. Expectiminimax tree
#     4.7.7. Finger tree
#     4.7.8. Expression tree
#     4.7.9. Log-structured merge-tree
# 5.Hash-based structures
#   5.1. Bloom filter
#   5.2. Binary fuse filter
#   5.3. Cuckoo filter
#   5.4. Xor filter
#   5.6. Count-min sketch
#   5.7. Distributed hash table
#   5.8. Double hashing
#   5.9. Dynamic perfect hash table
#   5.10. Hash array mapped trie
#   5.11. Hash list
#   5.12. Hash table
#   5.13. Hash tree
#   5.14. Hash trie
#   5.15. Koorde
#   5.16. Perfix hash tree
#   5.17. Rolling hash
#   5.18. Minhash
#   5.19. Quotient filter
#   5.20. Ctrie
# 6. Graph
#
#
# // see also list of algorithms
# https://en.wikipedia.org/wiki/List_of_algorithms
